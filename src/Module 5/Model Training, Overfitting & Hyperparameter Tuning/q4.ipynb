# %% [markdown]
# Question 4: Hyperparameter Tuning with RandomizedSearchCV<br>
# Task: Use RandomizedSearchCV to optimize hyperparameters for a RandomForestClassifier.

# %%
import numpy as np
from sklearn.model_selection import train_test_split, RandomizedSearchCV
from sklearn.ensemble import RandomForestClassifier
from sklearn.datasets import load_iris
from scipy.stats import randint

# Load the Iris dataset (classification problem)
data = load_iris()
X = data.data
y = data.target

# Split data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# Initialize a RandomForestClassifier
rf_classifier = RandomForestClassifier(random_state=42)

# Define the parameter grid for RandomizedSearchCV
param_dist = {
    'n_estimators': randint(50, 200),  # Number of trees
        'max_depth': randint(3, 20),       # Maximum depth of the tree
            'min_samples_split': randint(2, 20),  # Minimum samples to split
                'min_samples_leaf': randint(1, 20),   # Minimum samples in a leaf node
                    'max_features': ['sqrt', 'log2'],  # Corrected max_features values
                        'bootstrap': [True, False]          # Whether to use bootstrap samples
                        }

# Initialize RandomizedSearchCV with 5-fold cross-validation and 100 iterations
random_search = RandomizedSearchCV(estimator=rf_classifier, param_distributions=param_dist, 
                                   n_iter=100, cv=5, verbose=2, random_state=42, n_jobs=-1)

# Perform RandomizedSearchCV to find the best hyperparameters
random_search.fit(X_train, y_train)

# Print the best hyperparameters
print(f"Best Hyperparameters: {random_search.best_params_}")

# Evaluate the model on the test set
best_rf_model = random_search.best_estimator_
test_accuracy = best_rf_model.score(X_test, y_test)
print(f"Test Set Accuracy: {test_accuracy:.2f}")
# Out:
# Fitting 5 folds for each of 100 candidates, totalling 500 fits
# [CV] END bootstrap=True, max_depth=17, max_features=sqrt, min_samples_leaf=8, min_samples_split=8, n_estimators=171; total time=   0.3s
# [CV] END bootstrap=True, max_depth=17, max_features=sqrt, min_samples_leaf=8, min_samples_split=8, n_estimators=171; total time=   0.3s
# [CV] END bootstrap=True, max_depth=17, max_features=sqrt, min_samples_leaf=8, min_samples_split=8, n_estimators=171; total time=   0.3s
# [CV] END bootstrap=True, max_depth=17, max_features=sqrt, min_samples_leaf=8, min_samples_split=8, n_estimators=171; total time=   0.4s
# [CV] END bootstrap=True, max_depth=17, max_features=sqrt, min_samples_leaf=8, min_samples_split=8, n_estimators=171; total time=   0.4s
# [CV] END bootstrap=True, max_depth=13, max_features=sqrt, min_samples_leaf=4, min_samples_split=9, n_estimators=180; total time=   0.4s
# [CV] END bootstrap=True, max_depth=13, max_features=sqrt, min_samples_leaf=4, min_samples_split=9, n_estimators=180; total time=   0.3s
# [CV] END bootstrap=True, max_depth=13, max_features=sqrt, min_samples_leaf=4, min_samples_split=9, n_estimators=180; total time=   0.3s
# [CV] END bootstrap=True, max_depth=13, max_features=sqrt, min_samples_leaf=4, min_samples_split=9, n_estimators=180; total time=   0.3s
# [CV] END bootstrap=True, max_depth=13, max_features=sqrt, min_samples_leaf=4, min_samples_split=9, n_estimators=180; total time=   0.4s
# [CV] END bootstrap=False, max_depth=4, max_features=log2, min_samples_leaf=12, min_samples_split=7, n_estimators=179; total time=   0.3s
# [CV] END bootstrap=False, max_depth=4, max_features=log2, min_samples_leaf=12, min_samples_split=7, n_estimators=179; total time=   0.3s
# [CV] END bootstrap=False, max_depth=4, max_features=log2, min_samples_leaf=12, min_samples_split=7, n_estimators=179; total time=   0.2s
# [CV] END bootstrap=False, max_depth=4, max_features=log2, min_samples_leaf=12, min_samples_split=7, n_estimators=179; total time=   0.3s
# [CV] END bootstrap=False, max_depth=4, max_features=log2, min_samples_leaf=12, min_samples_split=7, n_estimators=179; total time=   0.2s
# [CV] END bootstrap=False, max_depth=3, max_features=log2, min_samples_leaf=12, min_samples_split=18, n_estimators=108; total time=   0.2s
# [CV] END bootstrap=False, max_depth=3, max_features=log2, min_samples_leaf=12, min_samples_split=18, n_estimators=108; total time=   0.1s
# [CV] END bootstrap=False, max_depth=3, max_features=log2, min_samples_leaf=12, min_samples_split=18, n_estimators=108; total time=   0.2s
# [CV] END bootstrap=False, max_depth=3, max_features=log2, min_samples_leaf=12, min_samples_split=18, n_estimators=108; total time=   0.1s
# [CV] END bootstrap=False, max_depth=3, max_features=log2, min_samples_leaf=12, min_samples_split=18, n_estimators=108; total time=   0.2s
# [CV] END bootstrap=True, max_depth=12, max_features=log2, min_samples_leaf=16, min_samples_split=16, n_estimators=100; total time=   0.2s
# [CV] END bootstrap=True, max_depth=12, max_features=log2, min_samples_leaf=16, min_samples_split=16, n_estimators=100; total time=   0.2s
# [CV] END bootstrap=True, max_depth=12, max_features=log2, min_samples_leaf=16, min_samples_split=16, n_estimators=100; total time=   0.3s
# [CV] END bootstrap=True, max_depth=12, max_features=log2, min_samples_leaf=16, min_samples_split=16, n_estimators=100; total time=   0.2s
# [CV] END bootstrap=False, max_depth=5, max_features=sqrt, min_samples_leaf=19, min_samples_split=8, n_estimators=70; total time=   0.1s
# [CV] END bootstrap=True, max_depth=12, max_features=log2, min_samples_leaf=16, min_samples_split=16, n_estimators=100; total time=   0.2s
# [CV] END bootstrap=False, max_depth=5, max_features=sqrt, min_samples_leaf=19, min_samples_split=8, n_estimators=70; total time=   0.1s
# [CV] END bootstrap=False, max_depth=5, max_features=sqrt, min_samples_leaf=19, min_samples_split=8, n_estimators=70; total time=   0.1s
# [CV] END bootstrap=False, max_depth=5, max_features=sqrt, min_samples_leaf=19, min_samples_split=8, n_estimators=70; total time=   0.1s
# [CV] END bootstrap=False, max_depth=5, max_features=sqrt, min_samples_leaf=19, min_samples_split=8, n_estimators=70; total time=   0.1s
# [CV] END bootstrap=True, max_depth=9, max_features=log2, min_samples_leaf=4, min_samples_split=15, n_estimators=58; total time=   0.1s
# [CV] END bootstrap=True, max_depth=9, max_features=log2, min_samples_leaf=4, min_samples_split=15, n_estimators=58; total time=   0.1s
# [CV] END bootstrap=True, max_depth=9, max_features=log2, min_samples_leaf=4, min_samples_split=15, n_estimators=58; total time=   0.1s
# [CV] END bootstrap=True, max_depth=9, max_features=log2, min_samples_leaf=4, min_samples_split=15, n_estimators=58; total time=   0.1s
# [CV] END bootstrap=True, max_depth=9, max_features=log2, min_samples_leaf=4, min_samples_split=15, n_estimators=58; total time=   0.1s
# [CV] END bootstrap=False, max_depth=4, max_features=log2, min_samples_leaf=15, min_samples_split=8, n_estimators=57; total time=   0.1s
# [CV] END bootstrap=False, max_depth=4, max_features=log2, min_samples_leaf=15, min_samples_split=8, n_estimators=57; total time=   0.1s
# [CV] END bootstrap=False, max_depth=4, max_features=log2, min_samples_leaf=15, min_samples_split=8, n_estimators=57; total time=   0.1s
# [CV] END bootstrap=False, max_depth=4, max_features=log2, min_samples_leaf=15, min_samples_split=8, n_estimators=57; total time=   0.1s
# [CV] END bootstrap=False, max_depth=4, max_features=log2, min_samples_leaf=15, min_samples_split=8, n_estimators=57; total time=   0.1s
# [CV] END bootstrap=True, max_depth=5, max_features=log2, min_samples_leaf=17, min_samples_split=5, n_estimators=99; total time=   0.2s
# [CV] END bootstrap=True, max_depth=5, max_features=log2, min_samples_leaf=17, min_samples_split=5, n_estimators=99; total time=   0.2s
# [CV] END bootstrap=True, max_depth=5, max_features=log2, min_samples_leaf=17, min_samples_split=5, n_estimators=99; total time=   0.2s
# [CV] END bootstrap=True, max_depth=5, max_features=log2, min_samples_leaf=17, min_samples_split=5, n_estimators=99; total time=   0.2s
# [CV] END bootstrap=False, max_depth=6, max_features=log2, min_samples_leaf=6, min_samples_split=11, n_estimators=53; total time=   0.1s
# [CV] END bootstrap=False, max_depth=6, max_features=log2, min_samples_leaf=6, min_samples_split=11, n_estimators=53; total time=   0.1s
# [CV] END bootstrap=True, max_depth=5, max_features=log2, min_samples_leaf=17, min_samples_split=5, n_estimators=99; total time=   0.2s
# [CV] END bootstrap=False, max_depth=6, max_features=log2, min_samples_leaf=6, min_samples_split=11, n_estimators=53; total time=   0.1s
# [CV] END bootstrap=False, max_depth=6, max_features=log2, min_samples_leaf=6, min_samples_split=11, n_estimators=53; total time=   0.1s
# [CV] END bootstrap=False, max_depth=14, max_features=log2, min_samples_leaf=10, min_samples_split=5, n_estimators=63; total time=   0.1s
# [CV] END bootstrap=False, max_depth=6, max_features=log2, min_samples_leaf=6, min_samples_split=11, n_estimators=53; total time=   0.2s
# [CV] END bootstrap=False, max_depth=14, max_features=log2, min_samples_leaf=10, min_samples_split=5, n_estimators=63; total time=   0.1s
# [CV] END bootstrap=False, max_depth=14, max_features=log2, min_samples_leaf=10, min_samples_split=5, n_estimators=63; total time=   0.1s
# [CV] END bootstrap=False, max_depth=14, max_features=log2, min_samples_leaf=10, min_samples_split=5, n_estimators=63; total time=   0.1s
# [CV] END bootstrap=False, max_depth=14, max_features=log2, min_samples_leaf=10, min_samples_split=5, n_estimators=63; total time=   0.1s
# [CV] END bootstrap=True, max_depth=18, max_features=sqrt, min_samples_leaf=8, min_samples_split=15, n_estimators=89; total time=   0.2s
# [CV] END bootstrap=True, max_depth=18, max_features=sqrt, min_samples_leaf=8, min_samples_split=15, n_estimators=89; total time=   0.2s
# [CV] END bootstrap=True, max_depth=18, max_features=sqrt, min_samples_leaf=8, min_samples_split=15, n_estimators=89; total time=   0.2s
# [CV] END bootstrap=True, max_depth=18, max_features=sqrt, min_samples_leaf=8, min_samples_split=15, n_estimators=89; total time=   0.2s
# [CV] END bootstrap=True, max_depth=18, max_features=sqrt, min_samples_leaf=8, min_samples_split=15, n_estimators=89; total time=   0.2s
# [CV] END bootstrap=True, max_depth=18, max_features=sqrt, min_samples_leaf=18, min_samples_split=16, n_estimators=102; total time=   0.2s
# [CV] END bootstrap=True, max_depth=18, max_features=sqrt, min_samples_leaf=18, min_samples_split=16, n_estimators=102; total time=   0.2s
# [CV] END bootstrap=True, max_depth=18, max_features=sqrt, min_samples_leaf=18, min_samples_split=16, n_estimators=102; total time=   0.2s
# [CV] END bootstrap=True, max_depth=18, max_features=sqrt, min_samples_leaf=18, min_samples_split=16, n_estimators=102; total time=   0.2s
# [CV] END bootstrap=True, max_depth=18, max_features=sqrt, min_samples_leaf=18, min_samples_split=16, n_estimators=102; total time=   0.2s
# [CV] END bootstrap=False, max_depth=15, max_features=sqrt, min_samples_leaf=15, min_samples_split=14, n_estimators=114; total time=   0.2s
# [CV] END bootstrap=False, max_depth=15, max_features=sqrt, min_samples_leaf=15, min_samples_split=14, n_estimators=114; total time=   0.2s
# [CV] END bootstrap=False, max_depth=15, max_features=sqrt, min_samples_leaf=15, min_samples_split=14, n_estimators=114; total time=   0.2s
# [CV] END bootstrap=False, max_depth=15, max_features=sqrt, min_samples_leaf=15, min_samples_split=14, n_estimators=114; total time=   0.2s
# [CV] END bootstrap=False, max_depth=15, max_features=sqrt, min_samples_leaf=15, min_samples_split=14, n_estimators=114; total time=   0.2s
# [CV] END bootstrap=True, max_depth=9, max_features=sqrt, min_samples_leaf=1, min_samples_split=13, n_estimators=185; total time=   0.3s
# [CV] END bootstrap=True, max_depth=9, max_features=sqrt, min_samples_leaf=1, min_samples_split=13, n_estimators=185; total time=   0.4s
# [CV] END bootstrap=True, max_depth=9, max_features=sqrt, min_samples_leaf=1, min_samples_split=13, n_estimators=185; total time=   0.4s
# [CV] END bootstrap=True, max_depth=9, max_features=sqrt, min_samples_leaf=1, min_samples_split=13, n_estimators=185; total time=   0.4s
# [CV] END bootstrap=False, max_depth=13, max_features=sqrt, min_samples_leaf=17, min_samples_split=9, n_estimators=82; total time=   0.1s
# [CV] END bootstrap=False, max_depth=13, max_features=sqrt, min_samples_leaf=17, min_samples_split=9, n_estimators=82; total time=   0.2s
# [CV] END bootstrap=True, max_depth=9, max_features=sqrt, min_samples_leaf=1, min_samples_split=13, n_estimators=185; total time=   0.4s
# [CV] END bootstrap=False, max_depth=13, max_features=sqrt, min_samples_leaf=17, min_samples_split=9, n_estimators=82; total time=   0.1s
# [CV] END bootstrap=False, max_depth=13, max_features=sqrt, min_samples_leaf=17, min_samples_split=9, n_estimators=82; total time=   0.1s
# [CV] END bootstrap=False, max_depth=13, max_features=sqrt, min_samples_leaf=17, min_samples_split=9, n_estimators=82; total time=   0.1s
# [CV] END bootstrap=True, max_depth=7, max_features=log2, min_samples_leaf=7, min_samples_split=10, n_estimators=77; total time=   0.1s
# [CV] END bootstrap=True, max_depth=7, max_features=log2, min_samples_leaf=7, min_samples_split=10, n_estimators=77; total time=   0.1s
# [CV] END bootstrap=True, max_depth=7, max_features=log2, min_samples_leaf=7, min_samples_split=10, n_estimators=77; total time=   0.1s
# [CV] END bootstrap=True, max_depth=7, max_features=log2, min_samples_leaf=7, min_samples_split=10, n_estimators=77; total time=   0.2s
# [CV] END bootstrap=True, max_depth=7, max_features=log2, min_samples_leaf=7, min_samples_split=10, n_estimators=77; total time=   0.2s
# [CV] END bootstrap=True, max_depth=11, max_features=log2, min_samples_leaf=12, min_samples_split=3, n_estimators=82; total time=   0.2s
# [CV] END bootstrap=True, max_depth=11, max_features=log2, min_samples_leaf=12, min_samples_split=3, n_estimators=82; total time=   0.2s
# [CV] END bootstrap=True, max_depth=11, max_features=log2, min_samples_leaf=12, min_samples_split=3, n_estimators=82; total time=   0.1s
# [CV] END bootstrap=True, max_depth=11, max_features=log2, min_samples_leaf=12, min_samples_split=3, n_estimators=82; total time=   0.1s
# [CV] END bootstrap=False, max_depth=7, max_features=sqrt, min_samples_leaf=12, min_samples_split=9, n_estimators=84; total time=   0.1s
# [CV] END bootstrap=True, max_depth=11, max_features=log2, min_samples_leaf=12, min_samples_split=3, n_estimators=82; total time=   0.2s
# [CV] END bootstrap=False, max_depth=7, max_features=sqrt, min_samples_leaf=12, min_samples_split=9, n_estimators=84; total time=   0.1s
# [CV] END bootstrap=False, max_depth=7, max_features=sqrt, min_samples_leaf=12, min_samples_split=9, n_estimators=84; total time=   0.1s
# [CV] END bootstrap=False, max_depth=7, max_features=sqrt, min_samples_leaf=12, min_samples_split=9, n_estimators=84; total time=   0.1s
# [CV] END bootstrap=False, max_depth=7, max_features=sqrt, min_samples_leaf=12, min_samples_split=9, n_estimators=84; total time=   0.1s
# [CV] END bootstrap=True, max_depth=5, max_features=sqrt, min_samples_leaf=15, min_samples_split=15, n_estimators=180; total time=   0.3s
# [CV] END bootstrap=True, max_depth=5, max_features=sqrt, min_samples_leaf=15, min_samples_split=15, n_estimators=180; total time=   0.3s
# [CV] END bootstrap=True, max_depth=5, max_features=sqrt, min_samples_leaf=15, min_samples_split=15, n_estimators=180; total time=   0.3s
# [CV] END bootstrap=True, max_depth=5, max_features=sqrt, min_samples_leaf=15, min_samples_split=15, n_estimators=180; total time=   0.3s
# [CV] END bootstrap=True, max_depth=7, max_features=log2, min_samples_leaf=14, min_samples_split=8, n_estimators=76; total time=   0.2s
# [CV] END bootstrap=True, max_depth=7, max_features=log2, min_samples_leaf=14, min_samples_split=8, n_estimators=76; total time=   0.2s
# [CV] END bootstrap=True, max_depth=5, max_features=sqrt, min_samples_leaf=15, min_samples_split=15, n_estimators=180; total time=   0.5s
# [CV] END bootstrap=True, max_depth=7, max_features=log2, min_samples_leaf=14, min_samples_split=8, n_estimators=76; total time=   0.2s
# [CV] END bootstrap=True, max_depth=7, max_features=log2, min_samples_leaf=14, min_samples_split=8, n_estimators=76; total time=   0.2s
# [CV] END bootstrap=True, max_depth=7, max_features=log2, min_samples_leaf=14, min_samples_split=8, n_estimators=76; total time=   0.2s
# [CV] END bootstrap=True, max_depth=17, max_features=sqrt, min_samples_leaf=10, min_samples_split=14, n_estimators=112; total time=   0.2s
# [CV] END bootstrap=True, max_depth=17, max_features=sqrt, min_samples_leaf=10, min_samples_split=14, n_estimators=112; total time=   0.2s
# [CV] END bootstrap=True, max_depth=17, max_features=sqrt, min_samples_leaf=10, min_samples_split=14, n_estimators=112; total time=   0.2s
# [CV] END bootstrap=True, max_depth=17, max_features=sqrt, min_samples_leaf=10, min_samples_split=14, n_estimators=112; total time=   0.2s
# [CV] END bootstrap=True, max_depth=17, max_features=sqrt, min_samples_leaf=10, min_samples_split=14, n_estimators=112; total time=   0.2s
# [CV] END bootstrap=False, max_depth=9, max_features=sqrt, min_samples_leaf=4, min_samples_split=6, n_estimators=192; total time=   0.3s
# [CV] END bootstrap=False, max_depth=9, max_features=sqrt, min_samples_leaf=4, min_samples_split=6, n_estimators=192; total time=   0.3s
# [CV] END bootstrap=False, max_depth=9, max_features=sqrt, min_samples_leaf=4, min_samples_split=6, n_estimators=192; total time=   0.3s
# [CV] END bootstrap=False, max_depth=9, max_features=sqrt, min_samples_leaf=4, min_samples_split=6, n_estimators=192; total time=   0.3s
# [CV] END bootstrap=True, max_depth=6, max_features=sqrt, min_samples_leaf=7, min_samples_split=3, n_estimators=94; total time=   0.2s
# [CV] END bootstrap=False, max_depth=9, max_features=sqrt, min_samples_leaf=4, min_samples_split=6, n_estimators=192; total time=   0.3s
# [CV] END bootstrap=True, max_depth=6, max_features=sqrt, min_samples_leaf=7, min_samples_split=3, n_estimators=94; total time=   0.2s
# [CV] END bootstrap=True, max_depth=6, max_features=sqrt, min_samples_leaf=7, min_samples_split=3, n_estimators=94; total time=   0.2s
# [CV] END bootstrap=True, max_depth=6, max_features=sqrt, min_samples_leaf=7, min_samples_split=3, n_estimators=94; total time=   0.2s
# [CV] END bootstrap=True, max_depth=6, max_features=sqrt, min_samples_leaf=7, min_samples_split=3, n_estimators=94; total time=   0.2s
# [CV] END bootstrap=False, max_depth=8, max_features=log2, min_samples_leaf=12, min_samples_split=13, n_estimators=133; total time=   0.2s
# [CV] END bootstrap=False, max_depth=8, max_features=log2, min_samples_leaf=12, min_samples_split=13, n_estimators=133; total time=   0.3s
# [CV] END bootstrap=False, max_depth=8, max_features=log2, min_samples_leaf=12, min_samples_split=13, n_estimators=133; total time=   0.3s
# [CV] END bootstrap=False, max_depth=8, max_features=log2, min_samples_leaf=12, min_samples_split=13, n_estimators=133; total time=   0.3s
# [CV] END bootstrap=False, max_depth=8, max_features=log2, min_samples_leaf=12, min_samples_split=13, n_estimators=133; total time=   0.2s
# [CV] END bootstrap=False, max_depth=13, max_features=log2, min_samples_leaf=7, min_samples_split=2, n_estimators=178; total time=   0.3s
# [CV] END bootstrap=False, max_depth=13, max_features=log2, min_samples_leaf=7, min_samples_split=2, n_estimators=178; total time=   0.3s
# [CV] END bootstrap=False, max_depth=13, max_features=log2, min_samples_leaf=7, min_samples_split=2, n_estimators=178; total time=   0.2s
# [CV] END bootstrap=False, max_depth=13, max_features=log2, min_samples_leaf=7, min_samples_split=2, n_estimators=178; total time=   0.3s
# [CV] END bootstrap=False, max_depth=13, max_features=log2, min_samples_leaf=7, min_samples_split=2, n_estimators=178; total time=   0.3s
# [CV] END bootstrap=True, max_depth=15, max_features=sqrt, min_samples_leaf=3, min_samples_split=8, n_estimators=186; total time=   0.3s
# [CV] END bootstrap=True, max_depth=15, max_features=sqrt, min_samples_leaf=3, min_samples_split=8, n_estimators=186; total time=   0.3s
# [CV] END bootstrap=True, max_depth=15, max_features=sqrt, min_samples_leaf=3, min_samples_split=8, n_estimators=186; total time=   0.3s
# [CV] END bootstrap=True, max_depth=15, max_features=sqrt, min_samples_leaf=3, min_samples_split=8, n_estimators=186; total time=   0.3s
# [CV] END bootstrap=False, max_depth=7, max_features=sqrt, min_samples_leaf=19, min_samples_split=11, n_estimators=108; total time=   0.2s
# [CV] END bootstrap=True, max_depth=15, max_features=sqrt, min_samples_leaf=3, min_samples_split=8, n_estimators=186; total time=   0.4s
# [CV] END bootstrap=False, max_depth=7, max_features=sqrt, min_samples_leaf=19, min_samples_split=11, n_estimators=108; total time=   0.2s
# [CV] END bootstrap=False, max_depth=7, max_features=sqrt, min_samples_leaf=19, min_samples_split=11, n_estimators=108; total time=   0.2s
# [CV] END bootstrap=False, max_depth=7, max_features=sqrt, min_samples_leaf=19, min_samples_split=11, n_estimators=108; total time=   0.2s
# [CV] END bootstrap=False, max_depth=7, max_features=sqrt, min_samples_leaf=19, min_samples_split=11, n_estimators=108; total time=   0.1s
# [CV] END bootstrap=False, max_depth=11, max_features=log2, min_samples_leaf=17, min_samples_split=18, n_estimators=101; total time=   0.1s
# [CV] END bootstrap=False, max_depth=11, max_features=log2, min_samples_leaf=17, min_samples_split=18, n_estimators=101; total time=   0.2s
# [CV] END bootstrap=False, max_depth=11, max_features=log2, min_samples_leaf=17, min_samples_split=18, n_estimators=101; total time=   0.1s
# [CV] END bootstrap=False, max_depth=11, max_features=log2, min_samples_leaf=17, min_samples_split=18, n_estimators=101; total time=   0.2s
# [CV] END bootstrap=False, max_depth=11, max_features=log2, min_samples_leaf=17, min_samples_split=18, n_estimators=101; total time=   0.2s
# [CV] END bootstrap=False, max_depth=9, max_features=log2, min_samples_leaf=3, min_samples_split=18, n_estimators=150; total time=   0.2s
# [CV] END bootstrap=False, max_depth=9, max_features=log2, min_samples_leaf=3, min_samples_split=18, n_estimators=150; total time=   0.2s
# [CV] END bootstrap=False, max_depth=9, max_features=log2, min_samples_leaf=3, min_samples_split=18, n_estimators=150; total time=   0.2s
# [CV] END bootstrap=False, max_depth=9, max_features=log2, min_samples_leaf=3, min_samples_split=18, n_estimators=150; total time=   0.3s
# [CV] END bootstrap=False, max_depth=9, max_features=log2, min_samples_leaf=3, min_samples_split=18, n_estimators=150; total time=   0.6s
# [CV] END bootstrap=True, max_depth=19, max_features=sqrt, min_samples_leaf=17, min_samples_split=3, n_estimators=179; total time=   0.9s
# [CV] END bootstrap=True, max_depth=19, max_features=sqrt, min_samples_leaf=17, min_samples_split=3, n_estimators=179; total time=   0.7s
# [CV] END bootstrap=True, max_depth=19, max_features=sqrt, min_samples_leaf=17, min_samples_split=3, n_estimators=179; total time=   0.4s
# [CV] END bootstrap=True, max_depth=19, max_features=sqrt, min_samples_leaf=17, min_samples_split=3, n_estimators=179; total time=   0.3s
# [CV] END bootstrap=True, max_depth=19, max_features=sqrt, min_samples_leaf=17, min_samples_split=3, n_estimators=179; total time=   0.3s
# [CV] END bootstrap=False, max_depth=7, max_features=log2, min_samples_leaf=1, min_samples_split=2, n_estimators=196; total time=   0.4s
# [CV] END bootstrap=False, max_depth=7, max_features=log2, min_samples_leaf=1, min_samples_split=2, n_estimators=196; total time=   0.4s
# [CV] END bootstrap=False, max_depth=7, max_features=log2, min_samples_leaf=1, min_samples_split=2, n_estimators=196; total time=   0.3s
# [CV] END bootstrap=False, max_depth=7, max_features=log2, min_samples_leaf=1, min_samples_split=2, n_estimators=196; total time=   0.3s
# [CV] END bootstrap=False, max_depth=7, max_features=log2, min_samples_leaf=1, min_samples_split=2, n_estimators=196; total time=   0.3s
# [CV] END bootstrap=False, max_depth=4, max_features=sqrt, min_samples_leaf=12, min_samples_split=7, n_estimators=117; total time=   0.2s
# [CV] END bootstrap=False, max_depth=4, max_features=sqrt, min_samples_leaf=12, min_samples_split=7, n_estimators=117; total time=   0.2s
# [CV] END bootstrap=False, max_depth=4, max_features=sqrt, min_samples_leaf=12, min_samples_split=7, n_estimators=117; total time=   0.2s
# [CV] END bootstrap=False, max_depth=4, max_features=sqrt, min_samples_leaf=12, min_samples_split=7, n_estimators=117; total time=   0.2s
# [CV] END bootstrap=False, max_depth=4, max_features=sqrt, min_samples_leaf=12, min_samples_split=7, n_estimators=117; total time=   0.2s
# [CV] END bootstrap=True, max_depth=13, max_features=log2, min_samples_leaf=17, min_samples_split=7, n_estimators=73; total time=   0.2s
# [CV] END bootstrap=True, max_depth=13, max_features=log2, min_samples_leaf=17, min_samples_split=7, n_estimators=73; total time=   0.2s
# [CV] END bootstrap=True, max_depth=13, max_features=log2, min_samples_leaf=17, min_samples_split=7, n_estimators=73; total time=   0.1s
# [CV] END bootstrap=True, max_depth=13, max_features=log2, min_samples_leaf=17, min_samples_split=7, n_estimators=73; total time=   0.1s
# [CV] END bootstrap=True, max_depth=13, max_features=log2, min_samples_leaf=17, min_samples_split=7, n_estimators=73; total time=   0.1s
# [CV] END bootstrap=True, max_depth=4, max_features=log2, min_samples_leaf=11, min_samples_split=17, n_estimators=193; total time=   0.3s
# [CV] END bootstrap=True, max_depth=4, max_features=log2, min_samples_leaf=11, min_samples_split=17, n_estimators=193; total time=   0.3s
# [CV] END bootstrap=True, max_depth=4, max_features=log2, min_samples_leaf=11, min_samples_split=17, n_estimators=193; total time=   0.4s
# [CV] END bootstrap=True, max_depth=4, max_features=log2, min_samples_leaf=11, min_samples_split=17, n_estimators=193; total time=   0.4s
# [CV] END bootstrap=True, max_depth=11, max_features=log2, min_samples_leaf=6, min_samples_split=17, n_estimators=142; total time=   0.3s
# [CV] END bootstrap=True, max_depth=4, max_features=log2, min_samples_leaf=11, min_samples_split=17, n_estimators=193; total time=   0.3s
# [CV] END bootstrap=True, max_depth=11, max_features=log2, min_samples_leaf=6, min_samples_split=17, n_estimators=142; total time=   0.3s
# [CV] END bootstrap=True, max_depth=11, max_features=log2, min_samples_leaf=6, min_samples_split=17, n_estimators=142; total time=   0.3s
# [CV] END bootstrap=True, max_depth=11, max_features=log2, min_samples_leaf=6, min_samples_split=17, n_estimators=142; total time=   0.3s
# [CV] END bootstrap=True, max_depth=11, max_features=log2, min_samples_leaf=6, min_samples_split=17, n_estimators=142; total time=   0.3s
# [CV] END bootstrap=True, max_depth=6, max_features=sqrt, min_samples_leaf=3, min_samples_split=8, n_estimators=101; total time=   0.2s
# [CV] END bootstrap=True, max_depth=6, max_features=sqrt, min_samples_leaf=3, min_samples_split=8, n_estimators=101; total time=   0.2s
# [CV] END bootstrap=True, max_depth=6, max_features=sqrt, min_samples_leaf=3, min_samples_split=8, n_estimators=101; total time=   0.2s
# [CV] END bootstrap=True, max_depth=6, max_features=sqrt, min_samples_leaf=3, min_samples_split=8, n_estimators=101; total time=   0.3s
# [CV] END bootstrap=True, max_depth=6, max_features=sqrt, min_samples_leaf=3, min_samples_split=8, n_estimators=101; total time=   0.2s
# [CV] END bootstrap=True, max_depth=3, max_features=log2, min_samples_leaf=7, min_samples_split=19, n_estimators=153; total time=   0.3s
# [CV] END bootstrap=True, max_depth=3, max_features=log2, min_samples_leaf=7, min_samples_split=19, n_estimators=153; total time=   0.4s
# [CV] END bootstrap=True, max_depth=3, max_features=log2, min_samples_leaf=7, min_samples_split=19, n_estimators=153; total time=   0.3s
# [CV] END bootstrap=True, max_depth=3, max_features=log2, min_samples_leaf=7, min_samples_split=19, n_estimators=153; total time=   0.4s
# [CV] END bootstrap=True, max_depth=3, max_features=log2, min_samples_leaf=7, min_samples_split=19, n_estimators=153; total time=   0.3s
# [CV] END bootstrap=True, max_depth=13, max_features=log2, min_samples_leaf=18, min_samples_split=11, n_estimators=148; total time=   0.3s
# [CV] END bootstrap=True, max_depth=13, max_features=log2, min_samples_leaf=18, min_samples_split=11, n_estimators=148; total time=   0.3s
# [CV] END bootstrap=True, max_depth=13, max_features=log2, min_samples_leaf=18, min_samples_split=11, n_estimators=148; total time=   0.3s
# [CV] END bootstrap=True, max_depth=13, max_features=log2, min_samples_leaf=18, min_samples_split=11, n_estimators=148; total time=   0.3s
# [CV] END bootstrap=True, max_depth=18, max_features=log2, min_samples_leaf=16, min_samples_split=18, n_estimators=51; total time=   0.1s
# [CV] END bootstrap=True, max_depth=13, max_features=log2, min_samples_leaf=18, min_samples_split=11, n_estimators=148; total time=   0.3s
# [CV] END bootstrap=True, max_depth=18, max_features=log2, min_samples_leaf=16, min_samples_split=18, n_estimators=51; total time=   0.2s
# [CV] END bootstrap=True, max_depth=18, max_features=log2, min_samples_leaf=16, min_samples_split=18, n_estimators=51; total time=   0.1s
# [CV] END bootstrap=True, max_depth=18, max_features=log2, min_samples_leaf=16, min_samples_split=18, n_estimators=51; total time=   0.1s
# [CV] END bootstrap=True, max_depth=18, max_features=log2, min_samples_leaf=16, min_samples_split=18, n_estimators=51; total time=   0.1s
# [CV] END bootstrap=True, max_depth=18, max_features=log2, min_samples_leaf=12, min_samples_split=6, n_estimators=86; total time=   0.2s
# [CV] END bootstrap=True, max_depth=18, max_features=log2, min_samples_leaf=12, min_samples_split=6, n_estimators=86; total time=   0.2s
# [CV] END bootstrap=True, max_depth=18, max_features=log2, min_samples_leaf=12, min_samples_split=6, n_estimators=86; total time=   0.2s
# [CV] END bootstrap=True, max_depth=18, max_features=log2, min_samples_leaf=12, min_samples_split=6, n_estimators=86; total time=   0.2s
# [CV] END bootstrap=True, max_depth=18, max_features=log2, min_samples_leaf=12, min_samples_split=6, n_estimators=86; total time=   0.2s
# [CV] END bootstrap=False, max_depth=11, max_features=sqrt, min_samples_leaf=3, min_samples_split=17, n_estimators=180; total time=   0.2s
# [CV] END bootstrap=False, max_depth=11, max_features=sqrt, min_samples_leaf=3, min_samples_split=17, n_estimators=180; total time=   0.3s
# [CV] END bootstrap=False, max_depth=11, max_features=sqrt, min_samples_leaf=3, min_samples_split=17, n_estimators=180; total time=   0.3s
# [CV] END bootstrap=False, max_depth=11, max_features=sqrt, min_samples_leaf=3, min_samples_split=17, n_estimators=180; total time=   0.3s
# [CV] END bootstrap=False, max_depth=11, max_features=sqrt, min_samples_leaf=3, min_samples_split=17, n_estimators=180; total time=   0.3s
# [CV] END bootstrap=False, max_depth=3, max_features=log2, min_samples_leaf=11, min_samples_split=18, n_estimators=153; total time=   0.2s
# [CV] END bootstrap=False, max_depth=3, max_features=log2, min_samples_leaf=11, min_samples_split=18, n_estimators=153; total time=   0.2s
# [CV] END bootstrap=False, max_depth=3, max_features=log2, min_samples_leaf=11, min_samples_split=18, n_estimators=153; total time=   0.2s
# [CV] END bootstrap=False, max_depth=3, max_features=log2, min_samples_leaf=11, min_samples_split=18, n_estimators=153; total time=   0.2s
# [CV] END bootstrap=False, max_depth=3, max_features=log2, min_samples_leaf=11, min_samples_split=18, n_estimators=153; total time=   0.2s
# [CV] END bootstrap=False, max_depth=5, max_features=log2, min_samples_leaf=3, min_samples_split=19, n_estimators=177; total time=   0.3s
# [CV] END bootstrap=False, max_depth=5, max_features=log2, min_samples_leaf=3, min_samples_split=19, n_estimators=177; total time=   0.3s
# [CV] END bootstrap=False, max_depth=5, max_features=log2, min_samples_leaf=3, min_samples_split=19, n_estimators=177; total time=   0.2s
# [CV] END bootstrap=False, max_depth=5, max_features=log2, min_samples_leaf=3, min_samples_split=19, n_estimators=177; total time=   0.3s
# [CV] END bootstrap=False, max_depth=5, max_features=log2, min_samples_leaf=3, min_samples_split=19, n_estimators=177; total time=   0.4s
# [CV] END bootstrap=False, max_depth=4, max_features=log2, min_samples_leaf=3, min_samples_split=17, n_estimators=117; total time=   0.5s
# [CV] END bootstrap=False, max_depth=4, max_features=log2, min_samples_leaf=3, min_samples_split=17, n_estimators=117; total time=   0.5s
# [CV] END bootstrap=False, max_depth=4, max_features=log2, min_samples_leaf=3, min_samples_split=17, n_estimators=117; total time=   0.3s
# [CV] END bootstrap=False, max_depth=4, max_features=log2, min_samples_leaf=3, min_samples_split=17, n_estimators=117; total time=   0.2s
# [CV] END bootstrap=False, max_depth=4, max_features=log2, min_samples_leaf=3, min_samples_split=17, n_estimators=117; total time=   0.2s
# [CV] END bootstrap=True, max_depth=16, max_features=sqrt, min_samples_leaf=16, min_samples_split=9, n_estimators=184; total time=   0.4s
# [CV] END bootstrap=True, max_depth=16, max_features=sqrt, min_samples_leaf=16, min_samples_split=9, n_estimators=184; total time=   0.3s
# [CV] END bootstrap=True, max_depth=16, max_features=sqrt, min_samples_leaf=16, min_samples_split=9, n_estimators=184; total time=   0.4s
# [CV] END bootstrap=True, max_depth=16, max_features=sqrt, min_samples_leaf=16, min_samples_split=9, n_estimators=184; total time=   0.4s
# [CV] END bootstrap=True, max_depth=19, max_features=log2, min_samples_leaf=1, min_samples_split=17, n_estimators=164; total time=   0.3s
# [CV] END bootstrap=True, max_depth=16, max_features=sqrt, min_samples_leaf=16, min_samples_split=9, n_estimators=184; total time=   0.4s
# [CV] END bootstrap=True, max_depth=19, max_features=log2, min_samples_leaf=1, min_samples_split=17, n_estimators=164; total time=   0.3s
# [CV] END bootstrap=True, max_depth=19, max_features=log2, min_samples_leaf=1, min_samples_split=17, n_estimators=164; total time=   0.4s
# [CV] END bootstrap=True, max_depth=19, max_features=log2, min_samples_leaf=1, min_samples_split=17, n_estimators=164; total time=   0.3s
# [CV] END bootstrap=True, max_depth=19, max_features=log2, min_samples_leaf=1, min_samples_split=17, n_estimators=164; total time=   0.4s
# [CV] END bootstrap=False, max_depth=16, max_features=log2, min_samples_leaf=6, min_samples_split=7, n_estimators=158; total time=   0.2s
# [CV] END bootstrap=False, max_depth=16, max_features=log2, min_samples_leaf=6, min_samples_split=7, n_estimators=158; total time=   0.2s
# [CV] END bootstrap=False, max_depth=16, max_features=log2, min_samples_leaf=6, min_samples_split=7, n_estimators=158; total time=   0.2s
# [CV] END bootstrap=False, max_depth=16, max_features=log2, min_samples_leaf=6, min_samples_split=7, n_estimators=158; total time=   0.2s
# [CV] END bootstrap=False, max_depth=16, max_features=log2, min_samples_leaf=6, min_samples_split=7, n_estimators=158; total time=   0.2s
# [CV] END bootstrap=True, max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=77; total time=   0.1s
# [CV] END bootstrap=True, max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=77; total time=   0.2s
# [CV] END bootstrap=True, max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=77; total time=   0.2s
# [CV] END bootstrap=True, max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=77; total time=   0.1s
# [CV] END bootstrap=True, max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=77; total time=   0.1s
# [CV] END bootstrap=True, max_depth=3, max_features=sqrt, min_samples_leaf=16, min_samples_split=5, n_estimators=84; total time=   0.2s
# [CV] END bootstrap=True, max_depth=3, max_features=sqrt, min_samples_leaf=16, min_samples_split=5, n_estimators=84; total time=   0.2s
# [CV] END bootstrap=True, max_depth=3, max_features=sqrt, min_samples_leaf=16, min_samples_split=5, n_estimators=84; total time=   0.1s
# [CV] END bootstrap=True, max_depth=3, max_features=sqrt, min_samples_leaf=16, min_samples_split=5, n_estimators=84; total time=   0.2s
# [CV] END bootstrap=False, max_depth=19, max_features=log2, min_samples_leaf=17, min_samples_split=13, n_estimators=95; total time=   0.1s
# [CV] END bootstrap=True, max_depth=3, max_features=sqrt, min_samples_leaf=16, min_samples_split=5, n_estimators=84; total time=   0.2s
# [CV] END bootstrap=False, max_depth=19, max_features=log2, min_samples_leaf=17, min_samples_split=13, n_estimators=95; total time=   0.1s
# [CV] END bootstrap=False, max_depth=19, max_features=log2, min_samples_leaf=17, min_samples_split=13, n_estimators=95; total time=   0.1s
# [CV] END bootstrap=False, max_depth=19, max_features=log2, min_samples_leaf=17, min_samples_split=13, n_estimators=95; total time=   0.1s
# [CV] END bootstrap=False, max_depth=19, max_features=log2, min_samples_leaf=17, min_samples_split=13, n_estimators=95; total time=   0.2s
# [CV] END bootstrap=True, max_depth=8, max_features=sqrt, min_samples_leaf=9, min_samples_split=6, n_estimators=73; total time=   0.2s
# [CV] END bootstrap=True, max_depth=8, max_features=sqrt, min_samples_leaf=9, min_samples_split=6, n_estimators=73; total time=   0.2s
# [CV] END bootstrap=True, max_depth=8, max_features=sqrt, min_samples_leaf=9, min_samples_split=6, n_estimators=73; total time=   0.1s
# [CV] END bootstrap=True, max_depth=8, max_features=sqrt, min_samples_leaf=9, min_samples_split=6, n_estimators=73; total time=   0.1s
# [CV] END bootstrap=True, max_depth=8, max_features=sqrt, min_samples_leaf=9, min_samples_split=6, n_estimators=73; total time=   0.1s
# [CV] END bootstrap=True, max_depth=19, max_features=log2, min_samples_leaf=3, min_samples_split=2, n_estimators=165; total time=   0.3s
# [CV] END bootstrap=True, max_depth=19, max_features=log2, min_samples_leaf=3, min_samples_split=2, n_estimators=165; total time=   0.3s
# [CV] END bootstrap=True, max_depth=19, max_features=log2, min_samples_leaf=3, min_samples_split=2, n_estimators=165; total time=   0.3s
# [CV] END bootstrap=True, max_depth=19, max_features=log2, min_samples_leaf=3, min_samples_split=2, n_estimators=165; total time=   0.3s
# [CV] END bootstrap=True, max_depth=19, max_features=log2, min_samples_leaf=3, min_samples_split=2, n_estimators=165; total time=   0.3s
# [CV] END bootstrap=True, max_depth=3, max_features=log2, min_samples_leaf=3, min_samples_split=19, n_estimators=74; total time=   0.1s
# [CV] END bootstrap=True, max_depth=3, max_features=log2, min_samples_leaf=3, min_samples_split=19, n_estimators=74; total time=   0.1s
# [CV] END bootstrap=True, max_depth=3, max_features=log2, min_samples_leaf=3, min_samples_split=19, n_estimators=74; total time=   0.1s
# [CV] END bootstrap=True, max_depth=3, max_features=log2, min_samples_leaf=3, min_samples_split=19, n_estimators=74; total time=   0.1s
# [CV] END bootstrap=True, max_depth=3, max_features=log2, min_samples_leaf=3, min_samples_split=19, n_estimators=74; total time=   0.1s
# [CV] END bootstrap=False, max_depth=5, max_features=log2, min_samples_leaf=14, min_samples_split=19, n_estimators=81; total time=   0.1s
# [CV] END bootstrap=False, max_depth=5, max_features=log2, min_samples_leaf=14, min_samples_split=19, n_estimators=81; total time=   0.1s
# [CV] END bootstrap=False, max_depth=5, max_features=log2, min_samples_leaf=14, min_samples_split=19, n_estimators=81; total time=   0.1s
# [CV] END bootstrap=False, max_depth=5, max_features=log2, min_samples_leaf=14, min_samples_split=19, n_estimators=81; total time=   0.1s
# [CV] END bootstrap=False, max_depth=5, max_features=log2, min_samples_leaf=14, min_samples_split=19, n_estimators=81; total time=   0.1s
# [CV] END bootstrap=True, max_depth=4, max_features=sqrt, min_samples_leaf=10, min_samples_split=3, n_estimators=66; total time=   0.1s
# [CV] END bootstrap=True, max_depth=4, max_features=sqrt, min_samples_leaf=10, min_samples_split=3, n_estimators=66; total time=   0.1s
# [CV] END bootstrap=True, max_depth=4, max_features=sqrt, min_samples_leaf=10, min_samples_split=3, n_estimators=66; total time=   0.1s
# [CV] END bootstrap=True, max_depth=4, max_features=sqrt, min_samples_leaf=10, min_samples_split=3, n_estimators=66; total time=   0.1s
# [CV] END bootstrap=True, max_depth=4, max_features=sqrt, min_samples_leaf=10, min_samples_split=3, n_estimators=66; total time=   0.1s
# [CV] END bootstrap=False, max_depth=3, max_features=sqrt, min_samples_leaf=11, min_samples_split=17, n_estimators=88; total time=   0.2s
# [CV] END bootstrap=False, max_depth=3, max_features=sqrt, min_samples_leaf=11, min_samples_split=17, n_estimators=88; total time=   0.2s
# [CV] END bootstrap=False, max_depth=3, max_features=sqrt, min_samples_leaf=11, min_samples_split=17, n_estimators=88; total time=   0.1s
# [CV] END bootstrap=False, max_depth=3, max_features=sqrt, min_samples_leaf=11, min_samples_split=17, n_estimators=88; total time=   0.1s
# [CV] END bootstrap=False, max_depth=3, max_features=sqrt, min_samples_leaf=11, min_samples_split=17, n_estimators=88; total time=   0.1s
# [CV] END bootstrap=True, max_depth=12, max_features=sqrt, min_samples_leaf=3, min_samples_split=19, n_estimators=62; total time=   0.1s
# [CV] END bootstrap=True, max_depth=12, max_features=sqrt, min_samples_leaf=3, min_samples_split=19, n_estimators=62; total time=   0.1s
# [CV] END bootstrap=True, max_depth=12, max_features=sqrt, min_samples_leaf=3, min_samples_split=19, n_estimators=62; total time=   0.2s
# [CV] END bootstrap=True, max_depth=12, max_features=sqrt, min_samples_leaf=3, min_samples_split=19, n_estimators=62; total time=   0.1s
# [CV] END bootstrap=True, max_depth=12, max_features=sqrt, min_samples_leaf=3, min_samples_split=19, n_estimators=62; total time=   0.2s
# [CV] END bootstrap=False, max_depth=9, max_features=sqrt, min_samples_leaf=4, min_samples_split=14, n_estimators=69; total time=   0.1s
# [CV] END bootstrap=False, max_depth=9, max_features=sqrt, min_samples_leaf=4, min_samples_split=14, n_estimators=69; total time=   0.1s
# [CV] END bootstrap=False, max_depth=9, max_features=sqrt, min_samples_leaf=4, min_samples_split=14, n_estimators=69; total time=   0.1s
# [CV] END bootstrap=False, max_depth=9, max_features=sqrt, min_samples_leaf=4, min_samples_split=14, n_estimators=69; total time=   0.1s
# [CV] END bootstrap=False, max_depth=9, max_features=sqrt, min_samples_leaf=4, min_samples_split=14, n_estimators=69; total time=   0.1s
# [CV] END bootstrap=True, max_depth=10, max_features=log2, min_samples_leaf=14, min_samples_split=17, n_estimators=191; total time=   0.4s
# [CV] END bootstrap=True, max_depth=10, max_features=log2, min_samples_leaf=14, min_samples_split=17, n_estimators=191; total time=   0.4s
# [CV] END bootstrap=True, max_depth=10, max_features=log2, min_samples_leaf=14, min_samples_split=17, n_estimators=191; total time=   0.3s
# [CV] END bootstrap=True, max_depth=10, max_features=log2, min_samples_leaf=14, min_samples_split=17, n_estimators=191; total time=   0.3s
# [CV] END bootstrap=False, max_depth=17, max_features=log2, min_samples_leaf=2, min_samples_split=3, n_estimators=81; total time=   0.1s
# [CV] END bootstrap=False, max_depth=17, max_features=log2, min_samples_leaf=2, min_samples_split=3, n_estimators=81; total time=   0.1s
# [CV] END bootstrap=True, max_depth=10, max_features=log2, min_samples_leaf=14, min_samples_split=17, n_estimators=191; total time=   0.3s
# [CV] END bootstrap=False, max_depth=17, max_features=log2, min_samples_leaf=2, min_samples_split=3, n_estimators=81; total time=   0.1s
# [CV] END bootstrap=False, max_depth=17, max_features=log2, min_samples_leaf=2, min_samples_split=3, n_estimators=81; total time=   0.2s
# [CV] END bootstrap=False, max_depth=17, max_features=log2, min_samples_leaf=2, min_samples_split=3, n_estimators=81; total time=   0.2s
# [CV] END bootstrap=True, max_depth=19, max_features=log2, min_samples_leaf=10, min_samples_split=7, n_estimators=64; total time=   0.1s
# [CV] END bootstrap=True, max_depth=19, max_features=log2, min_samples_leaf=10, min_samples_split=7, n_estimators=64; total time=   0.1s
# [CV] END bootstrap=True, max_depth=19, max_features=log2, min_samples_leaf=10, min_samples_split=7, n_estimators=64; total time=   0.1s
# [CV] END bootstrap=True, max_depth=19, max_features=log2, min_samples_leaf=10, min_samples_split=7, n_estimators=64; total time=   0.1s
# [CV] END bootstrap=False, max_depth=13, max_features=log2, min_samples_leaf=5, min_samples_split=2, n_estimators=57; total time=   0.1s
# [CV] END bootstrap=True, max_depth=19, max_features=log2, min_samples_leaf=10, min_samples_split=7, n_estimators=64; total time=   0.1s
# [CV] END bootstrap=False, max_depth=13, max_features=log2, min_samples_leaf=5, min_samples_split=2, n_estimators=57; total time=   0.1s
# [CV] END bootstrap=False, max_depth=13, max_features=log2, min_samples_leaf=5, min_samples_split=2, n_estimators=57; total time=   0.1s
# [CV] END bootstrap=False, max_depth=13, max_features=log2, min_samples_leaf=5, min_samples_split=2, n_estimators=57; total time=   0.1s
# [CV] END bootstrap=False, max_depth=13, max_features=log2, min_samples_leaf=5, min_samples_split=2, n_estimators=57; total time=   0.1s
# [CV] END bootstrap=True, max_depth=14, max_features=log2, min_samples_leaf=5, min_samples_split=8, n_estimators=55; total time=   0.1s
# [CV] END bootstrap=True, max_depth=14, max_features=log2, min_samples_leaf=5, min_samples_split=8, n_estimators=55; total time=   0.1s
# [CV] END bootstrap=True, max_depth=14, max_features=log2, min_samples_leaf=5, min_samples_split=8, n_estimators=55; total time=   0.1s
# [CV] END bootstrap=True, max_depth=14, max_features=log2, min_samples_leaf=5, min_samples_split=8, n_estimators=55; total time=   0.1s
# [CV] END bootstrap=True, max_depth=14, max_features=log2, min_samples_leaf=5, min_samples_split=8, n_estimators=55; total time=   0.1s
# [CV] END bootstrap=True, max_depth=17, max_features=sqrt, min_samples_leaf=8, min_samples_split=17, n_estimators=62; total time=   0.1s
# [CV] END bootstrap=True, max_depth=17, max_features=sqrt, min_samples_leaf=8, min_samples_split=17, n_estimators=62; total time=   0.1s
# [CV] END bootstrap=True, max_depth=17, max_features=sqrt, min_samples_leaf=8, min_samples_split=17, n_estimators=62; total time=   0.1s
# [CV] END bootstrap=True, max_depth=17, max_features=sqrt, min_samples_leaf=8, min_samples_split=17, n_estimators=62; total time=   0.1s
# [CV] END bootstrap=True, max_depth=17, max_features=sqrt, min_samples_leaf=8, min_samples_split=17, n_estimators=62; total time=   0.1s
# [CV] END bootstrap=False, max_depth=12, max_features=log2, min_samples_leaf=19, min_samples_split=18, n_estimators=169; total time=   0.3s
# [CV] END bootstrap=False, max_depth=12, max_features=log2, min_samples_leaf=19, min_samples_split=18, n_estimators=169; total time=   0.3s
# [CV] END bootstrap=False, max_depth=12, max_features=log2, min_samples_leaf=19, min_samples_split=18, n_estimators=169; total time=   0.2s
# [CV] END bootstrap=False, max_depth=12, max_features=log2, min_samples_leaf=19, min_samples_split=18, n_estimators=169; total time=   0.2s
# [CV] END bootstrap=False, max_depth=12, max_features=log2, min_samples_leaf=19, min_samples_split=18, n_estimators=169; total time=   0.3s
# [CV] END bootstrap=True, max_depth=7, max_features=log2, min_samples_leaf=9, min_samples_split=13, n_estimators=178; total time=   0.3s
# [CV] END bootstrap=True, max_depth=7, max_features=log2, min_samples_leaf=9, min_samples_split=13, n_estimators=178; total time=   0.4s
# [CV] END bootstrap=True, max_depth=7, max_features=log2, min_samples_leaf=9, min_samples_split=13, n_estimators=178; total time=   0.4s
# [CV] END bootstrap=True, max_depth=7, max_features=log2, min_samples_leaf=9, min_samples_split=13, n_estimators=178; total time=   0.4s
# [CV] END bootstrap=True, max_depth=7, max_features=log2, min_samples_leaf=9, min_samples_split=13, n_estimators=178; total time=   0.4s
# [CV] END bootstrap=False, max_depth=3, max_features=sqrt, min_samples_leaf=2, min_samples_split=17, n_estimators=138; total time=   0.2s
# [CV] END bootstrap=False, max_depth=3, max_features=sqrt, min_samples_leaf=2, min_samples_split=17, n_estimators=138; total time=   0.2s
# [CV] END bootstrap=False, max_depth=3, max_features=sqrt, min_samples_leaf=2, min_samples_split=17, n_estimators=138; total time=   0.2s
# [CV] END bootstrap=False, max_depth=3, max_features=sqrt, min_samples_leaf=2, min_samples_split=17, n_estimators=138; total time=   0.2s
# [CV] END bootstrap=False, max_depth=15, max_features=sqrt, min_samples_leaf=1, min_samples_split=17, n_estimators=118; total time=   0.2s
# [CV] END bootstrap=False, max_depth=3, max_features=sqrt, min_samples_leaf=2, min_samples_split=17, n_estimators=138; total time=   0.2s
# [CV] END bootstrap=False, max_depth=15, max_features=sqrt, min_samples_leaf=1, min_samples_split=17, n_estimators=118; total time=   0.2s
# [CV] END bootstrap=False, max_depth=15, max_features=sqrt, min_samples_leaf=1, min_samples_split=17, n_estimators=118; total time=   0.2s
# [CV] END bootstrap=False, max_depth=15, max_features=sqrt, min_samples_leaf=1, min_samples_split=17, n_estimators=118; total time=   0.2s
# [CV] END bootstrap=False, max_depth=15, max_features=sqrt, min_samples_leaf=1, min_samples_split=17, n_estimators=118; total time=   0.2s
# [CV] END bootstrap=False, max_depth=5, max_features=log2, min_samples_leaf=16, min_samples_split=6, n_estimators=135; total time=   0.2s
# [CV] END bootstrap=False, max_depth=5, max_features=log2, min_samples_leaf=16, min_samples_split=6, n_estimators=135; total time=   0.2s
# [CV] END bootstrap=False, max_depth=5, max_features=log2, min_samples_leaf=16, min_samples_split=6, n_estimators=135; total time=   0.2s
# [CV] END bootstrap=False, max_depth=5, max_features=log2, min_samples_leaf=16, min_samples_split=6, n_estimators=135; total time=   0.3s
# [CV] END bootstrap=False, max_depth=5, max_features=log2, min_samples_leaf=16, min_samples_split=6, n_estimators=135; total time=   0.3s
# [CV] END bootstrap=True, max_depth=16, max_features=log2, min_samples_leaf=5, min_samples_split=16, n_estimators=143; total time=   0.3s
# ...
# [CV] END bootstrap=True, max_depth=14, max_features=sqrt, min_samples_leaf=13, min_samples_split=13, n_estimators=144; total time=   0.3s
# [CV] END bootstrap=True, max_depth=14, max_features=sqrt, min_samples_leaf=13, min_samples_split=13, n_estimators=144; total time=   0.3s
# [CV] END bootstrap=True, max_depth=14, max_features=sqrt, min_samples_leaf=13, min_samples_split=13, n_estimators=144; total time=   0.3s
# [CV] END bootstrap=True, max_depth=14, max_features=sqrt, min_samples_leaf=13, min_samples_split=13, n_estimators=144; total time=   0.3s
# [CV] END bootstrap=True, max_depth=14, max_features=sqrt, min_samples_leaf=13, min_samples_split=13, n_estimators=144; total time=   0.3s
# [CV] END bootstrap=False, max_depth=4, max_features=sqrt, min_samples_leaf=19, min_samples_split=19, n_estimators=84; total time=   0.1s
# [CV] END bootstrap=False, max_depth=4, max_features=sqrt, min_samples_leaf=19, min_samples_split=19, n_estimators=84; total time=   0.2s
# [CV] END bootstrap=False, max_depth=4, max_features=sqrt, min_samples_leaf=19, min_samples_split=19, n_estimators=84; total time=   0.1s
# [CV] END bootstrap=False, max_depth=4, max_features=sqrt, min_samples_leaf=19, min_samples_split=19, n_estimators=84; total time=   0.1s
# [CV] END bootstrap=False, max_depth=4, max_features=sqrt, min_samples_leaf=19, min_samples_split=19, n_estimators=84; total time=   0.1s
# [CV] END bootstrap=True, max_depth=19, max_features=log2, min_samples_leaf=8, min_samples_split=11, n_estimators=139; total time=   0.3s
# [CV] END bootstrap=True, max_depth=19, max_features=log2, min_samples_leaf=8, min_samples_split=11, n_estimators=139; total time=   0.3s
# [CV] END bootstrap=True, max_depth=19, max_features=log2, min_samples_leaf=8, min_samples_split=11, n_estimators=139; total time=   0.3s
# [CV] END bootstrap=True, max_depth=19, max_features=log2, min_samples_leaf=8, min_samples_split=11, n_estimators=139; total time=   0.3s
# [CV] END bootstrap=False, max_depth=4, max_features=sqrt, min_samples_leaf=9, min_samples_split=8, n_estimators=107; total time=   0.2s
# [CV] END bootstrap=True, max_depth=19, max_features=log2, min_samples_leaf=8, min_samples_split=11, n_estimators=139; total time=   0.3s
# [CV] END bootstrap=False, max_depth=4, max_features=sqrt, min_samples_leaf=9, min_samples_split=8, n_estimators=107; total time=   0.2s
# [CV] END bootstrap=False, max_depth=4, max_features=sqrt, min_samples_leaf=9, min_samples_split=8, n_estimators=107; total time=   0.2s
# [CV] END bootstrap=False, max_depth=4, max_features=sqrt, min_samples_leaf=9, min_samples_split=8, n_estimators=107; total time=   0.2s
# [CV] END bootstrap=False, max_depth=4, max_features=sqrt, min_samples_leaf=9, min_samples_split=8, n_estimators=107; total time=   0.2s
# [CV] END bootstrap=True, max_depth=15, max_features=sqrt, min_samples_leaf=4, min_samples_split=5, n_estimators=187; total time=   0.4s
# [CV] END bootstrap=True, max_depth=15, max_features=sqrt, min_samples_leaf=4, min_samples_split=5, n_estimators=187; total time=   0.4s
# [CV] END bootstrap=True, max_depth=15, max_features=sqrt, min_samples_leaf=4, min_samples_split=5, n_estimators=187; total time=   0.3s
# [CV] END bootstrap=True, max_depth=15, max_features=sqrt, min_samples_leaf=4, min_samples_split=5, n_estimators=187; total time=   0.4s
# [CV] END bootstrap=True, max_depth=15, max_features=sqrt, min_samples_leaf=4, min_samples_split=5, n_estimators=187; total time=   0.4s
# [CV] END bootstrap=True, max_depth=11, max_features=log2, min_samples_leaf=3, min_samples_split=18, n_estimators=148; total time=   0.3s
# [CV] END bootstrap=True, max_depth=11, max_features=log2, min_samples_leaf=3, min_samples_split=18, n_estimators=148; total time=   0.3s
# [CV] END bootstrap=True, max_depth=11, max_features=log2, min_samples_leaf=3, min_samples_split=18, n_estimators=148; total time=   0.3s
# [CV] END bootstrap=True, max_depth=11, max_features=log2, min_samples_leaf=3, min_samples_split=18, n_estimators=148; total time=   0.3s
# [CV] END bootstrap=True, max_depth=11, max_features=log2, min_samples_leaf=3, min_samples_split=18, n_estimators=148; total time=   0.3s
# [CV] END bootstrap=False, max_depth=6, max_features=log2, min_samples_leaf=17, min_samples_split=8, n_estimators=145; total time=   0.2s
# [CV] END bootstrap=False, max_depth=6, max_features=log2, min_samples_leaf=17, min_samples_split=8, n_estimators=145; total time=   0.2s
# [CV] END bootstrap=False, max_depth=6, max_features=log2, min_samples_leaf=17, min_samples_split=8, n_estimators=145; total time=   0.2s
# [CV] END bootstrap=False, max_depth=6, max_features=log2, min_samples_leaf=17, min_samples_split=8, n_estimators=145; total time=   0.2s
# [CV] END bootstrap=False, max_depth=6, max_features=log2, min_samples_leaf=17, min_samples_split=8, n_estimators=145; total time=   0.2s
# [CV] END bootstrap=False, max_depth=7, max_features=log2, min_samples_leaf=17, min_samples_split=14, n_estimators=72; total time=   0.1s
# [CV] END bootstrap=False, max_depth=7, max_features=log2, min_samples_leaf=17, min_samples_split=14, n_estimators=72; total time=   0.1s
# [CV] END bootstrap=False, max_depth=7, max_features=log2, min_samples_leaf=17, min_samples_split=14, n_estimators=72; total time=   0.1s
# [CV] END bootstrap=False, max_depth=7, max_features=log2, min_samples_leaf=17, min_samples_split=14, n_estimators=72; total time=   0.1s
# [CV] END bootstrap=False, max_depth=7, max_features=log2, min_samples_leaf=17, min_samples_split=14, n_estimators=72; total time=   0.2s
# [CV] END bootstrap=True, max_depth=5, max_features=sqrt, min_samples_leaf=17, min_samples_split=18, n_estimators=111; total time=   0.2s
# [CV] END bootstrap=True, max_depth=5, max_features=sqrt, min_samples_leaf=17, min_samples_split=18, n_estimators=111; total time=   0.2s
# [CV] END bootstrap=True, max_depth=5, max_features=sqrt, min_samples_leaf=17, min_samples_split=18, n_estimators=111; total time=   0.2s
# [CV] END bootstrap=True, max_depth=5, max_features=sqrt, min_samples_leaf=17, min_samples_split=18, n_estimators=111; total time=   0.2s
# [CV] END bootstrap=True, max_depth=5, max_features=sqrt, min_samples_leaf=17, min_samples_split=18, n_estimators=111; total time=   0.2s
# [CV] END bootstrap=False, max_depth=18, max_features=sqrt, min_samples_leaf=13, min_samples_split=18, n_estimators=149; total time=   0.2s
# [CV] END bootstrap=False, max_depth=18, max_features=sqrt, min_samples_leaf=13, min_samples_split=18, n_estimators=149; total time=   0.2s
# [CV] END bootstrap=False, max_depth=18, max_features=sqrt, min_samples_leaf=13, min_samples_split=18, n_estimators=149; total time=   0.2s
# [CV] END bootstrap=False, max_depth=18, max_features=sqrt, min_samples_leaf=13, min_samples_split=18, n_estimators=149; total time=   0.2s
# [CV] END bootstrap=False, max_depth=18, max_features=sqrt, min_samples_leaf=13, min_samples_split=18, n_estimators=149; total time=   0.2s
# [CV] END bootstrap=False, max_depth=11, max_features=sqrt, min_samples_leaf=12, min_samples_split=10, n_estimators=77; total time=   0.1s
# [CV] END bootstrap=False, max_depth=11, max_features=sqrt, min_samples_leaf=12, min_samples_split=10, n_estimators=77; total time=   0.1s
# [CV] END bootstrap=False, max_depth=11, max_features=sqrt, min_samples_leaf=12, min_samples_split=10, n_estimators=77; total time=   0.1s
# [CV] END bootstrap=False, max_depth=11, max_features=sqrt, min_samples_leaf=12, min_samples_split=10, n_estimators=77; total time=   0.2s
# [CV] END bootstrap=False, max_depth=11, max_features=sqrt, min_samples_leaf=12, min_samples_split=10, n_estimators=77; total time=   0.1s
# [CV] END bootstrap=False, max_depth=17, max_features=log2, min_samples_leaf=5, min_samples_split=4, n_estimators=189; total time=   0.3s
# [CV] END bootstrap=False, max_depth=17, max_features=log2, min_samples_leaf=5, min_samples_split=4, n_estimators=189; total time=   0.3s
# [CV] END bootstrap=False, max_depth=17, max_features=log2, min_samples_leaf=5, min_samples_split=4, n_estimators=189; total time=   0.3s
# [CV] END bootstrap=False, max_depth=17, max_features=log2, min_samples_leaf=5, min_samples_split=4, n_estimators=189; total time=   0.3s
# [CV] END bootstrap=False, max_depth=17, max_features=log2, min_samples_leaf=5, min_samples_split=4, n_estimators=189; total time=   0.4s
# [CV] END bootstrap=True, max_depth=6, max_features=sqrt, min_samples_leaf=16, min_samples_split=8, n_estimators=158; total time=   0.4s
# [CV] END bootstrap=True, max_depth=6, max_features=sqrt, min_samples_leaf=16, min_samples_split=8, n_estimators=158; total time=   0.3s
# [CV] END bootstrap=True, max_depth=6, max_features=sqrt, min_samples_leaf=16, min_samples_split=8, n_estimators=158; total time=   0.3s
# [CV] END bootstrap=True, max_depth=6, max_features=sqrt, min_samples_leaf=16, min_samples_split=8, n_estimators=158; total time=   0.3s
# [CV] END bootstrap=True, max_depth=6, max_features=sqrt, min_samples_leaf=16, min_samples_split=8, n_estimators=158; total time=   0.3s
# [CV] END bootstrap=True, max_depth=12, max_features=log2, min_samples_leaf=7, min_samples_split=15, n_estimators=171; total time=   0.3s
# [CV] END bootstrap=True, max_depth=12, max_features=log2, min_samples_leaf=7, min_samples_split=15, n_estimators=171; total time=   0.3s
# [CV] END bootstrap=True, max_depth=12, max_features=log2, min_samples_leaf=7, min_samples_split=15, n_estimators=171; total time=   0.3s
# [CV] END bootstrap=True, max_depth=12, max_features=log2, min_samples_leaf=7, min_samples_split=15, n_estimators=171; total time=   0.3s
# [CV] END bootstrap=True, max_depth=12, max_features=log2, min_samples_leaf=7, min_samples_split=15, n_estimators=171; total time=   0.3s
# [CV] END bootstrap=True, max_depth=5, max_features=sqrt, min_samples_leaf=11, min_samples_split=12, n_estimators=195; total time=   0.3s
# [CV] END bootstrap=True, max_depth=5, max_features=sqrt, min_samples_leaf=11, min_samples_split=12, n_estimators=195; total time=   0.4s
# [CV] END bootstrap=True, max_depth=5, max_features=sqrt, min_samples_leaf=11, min_samples_split=12, n_estimators=195; total time=   0.4s
# [CV] END bootstrap=True, max_depth=5, max_features=sqrt, min_samples_leaf=11, min_samples_split=12, n_estimators=195; total time=   0.3s
# [CV] END bootstrap=True, max_depth=5, max_features=sqrt, min_samples_leaf=11, min_samples_split=12, n_estimators=195; total time=   0.4s
# [CV] END bootstrap=True, max_depth=14, max_features=sqrt, min_samples_leaf=10, min_samples_split=13, n_estimators=194; total time=   0.3s
# [CV] END bootstrap=True, max_depth=14, max_features=sqrt, min_samples_leaf=10, min_samples_split=13, n_estimators=194; total time=   0.4s
# [CV] END bootstrap=True, max_depth=14, max_features=sqrt, min_samples_leaf=10, min_samples_split=13, n_estimators=194; total time=   0.3s
# [CV] END bootstrap=True, max_depth=14, max_features=sqrt, min_samples_leaf=10, min_samples_split=13, n_estimators=194; total time=   0.4s
# [CV] END bootstrap=True, max_depth=14, max_features=sqrt, min_samples_leaf=10, min_samples_split=13, n_estimators=194; total time=   0.3s
# [CV] END bootstrap=True, max_depth=8, max_features=sqrt, min_samples_leaf=14, min_samples_split=14, n_estimators=186; total time=   0.3s
# [CV] END bootstrap=True, max_depth=8, max_features=sqrt, min_samples_leaf=14, min_samples_split=14, n_estimators=186; total time=   0.3s
# [CV] END bootstrap=True, max_depth=8, max_features=sqrt, min_samples_leaf=14, min_samples_split=14, n_estimators=186; total time=   0.3s
# [CV] END bootstrap=True, max_depth=8, max_features=sqrt, min_samples_leaf=14, min_samples_split=14, n_estimators=186; total time=   0.4s
# [CV] END bootstrap=True, max_depth=8, max_features=sqrt, min_samples_leaf=14, min_samples_split=14, n_estimators=186; total time=   0.4s
# [CV] END bootstrap=False, max_depth=4, max_features=sqrt, min_samples_leaf=5, min_samples_split=7, n_estimators=132; total time=   0.2s
# [CV] END bootstrap=False, max_depth=4, max_features=sqrt, min_samples_leaf=5, min_samples_split=7, n_estimators=132; total time=   0.2s
# [CV] END bootstrap=False, max_depth=4, max_features=sqrt, min_samples_leaf=5, min_samples_split=7, n_estimators=132; total time=   0.2s
# [CV] END bootstrap=False, max_depth=4, max_features=sqrt, min_samples_leaf=5, min_samples_split=7, n_estimators=132; total time=   0.2s
# [CV] END bootstrap=False, max_depth=4, max_features=sqrt, min_samples_leaf=5, min_samples_split=7, n_estimators=132; total time=   0.2s
# [CV] END bootstrap=False, max_depth=18, max_features=sqrt, min_samples_leaf=1, min_samples_split=18, n_estimators=120; total time=   0.2s
# [CV] END bootstrap=False, max_depth=18, max_features=sqrt, min_samples_leaf=1, min_samples_split=18, n_estimators=120; total time=   0.2s
# [CV] END bootstrap=False, max_depth=18, max_features=sqrt, min_samples_leaf=1, min_samples_split=18, n_estimators=120; total time=   0.2s
# [CV] END bootstrap=False, max_depth=18, max_features=sqrt, min_samples_leaf=1, min_samples_split=18, n_estimators=120; total time=   0.2s
# [CV] END bootstrap=False, max_depth=18, max_features=sqrt, min_samples_leaf=1, min_samples_split=18, n_estimators=120; total time=   0.2s
# [CV] END bootstrap=True, max_depth=15, max_features=log2, min_samples_leaf=4, min_samples_split=7, n_estimators=68; total time=   0.1s
# [CV] END bootstrap=True, max_depth=15, max_features=log2, min_samples_leaf=4, min_samples_split=7, n_estimators=68; total time=   0.1s
# [CV] END bootstrap=True, max_depth=15, max_features=log2, min_samples_leaf=4, min_samples_split=7, n_estimators=68; total time=   0.1s
# [CV] END bootstrap=True, max_depth=15, max_features=log2, min_samples_leaf=4, min_samples_split=7, n_estimators=68; total time=   0.2s
# [CV] END bootstrap=True, max_depth=15, max_features=log2, min_samples_leaf=4, min_samples_split=7, n_estimators=68; total time=   0.2s
# [CV] END bootstrap=True, max_depth=14, max_features=log2, min_samples_leaf=7, min_samples_split=11, n_estimators=139; total time=   0.3s
# [CV] END bootstrap=True, max_depth=14, max_features=log2, min_samples_leaf=7, min_samples_split=11, n_estimators=139; total time=   0.3s
# [CV] END bootstrap=True, max_depth=14, max_features=log2, min_samples_leaf=7, min_samples_split=11, n_estimators=139; total time=   0.3s
# [CV] END bootstrap=True, max_depth=14, max_features=log2, min_samples_leaf=7, min_samples_split=11, n_estimators=139; total time=   0.3s
# [CV] END bootstrap=True, max_depth=14, max_features=log2, min_samples_leaf=7, min_samples_split=11, n_estimators=139; total time=   0.3s
# [CV] END bootstrap=True, max_depth=9, max_features=log2, min_samples_leaf=3, min_samples_split=14, n_estimators=190; total time=   0.4s
# [CV] END bootstrap=True, max_depth=9, max_features=log2, min_samples_leaf=3, min_samples_split=14, n_estimators=190; total time=   0.4s
# [CV] END bootstrap=True, max_depth=9, max_features=log2, min_samples_leaf=3, min_samples_split=14, n_estimators=190; total time=   0.3s
# [CV] END bootstrap=True, max_depth=9, max_features=log2, min_samples_leaf=3, min_samples_split=14, n_estimators=190; total time=   0.4s
# [CV] END bootstrap=False, max_depth=10, max_features=sqrt, min_samples_leaf=9, min_samples_split=8, n_estimators=50; total time=   0.1s
# [CV] END bootstrap=True, max_depth=9, max_features=log2, min_samples_leaf=3, min_samples_split=14, n_estimators=190; total time=   0.3s
# [CV] END bootstrap=False, max_depth=10, max_features=sqrt, min_samples_leaf=9, min_samples_split=8, n_estimators=50; total time=   0.1s
# [CV] END bootstrap=False, max_depth=10, max_features=sqrt, min_samples_leaf=9, min_samples_split=8, n_estimators=50; total time=   0.1s
# [CV] END bootstrap=False, max_depth=10, max_features=sqrt, min_samples_leaf=9, min_samples_split=8, n_estimators=50; total time=   0.1s
# [CV] END bootstrap=False, max_depth=10, max_features=sqrt, min_samples_leaf=9, min_samples_split=8, n_estimators=50; total time=   0.1s
# Best Hyperparameters: {'bootstrap': True, 'max_depth': 17, 'max_features': 'sqrt', 'min_samples_leaf': 8, 'min_samples_split': 8, 'n_estimators': 171}
# Test Set Accuracy: 1.00

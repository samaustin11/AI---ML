# %% [markdown]
# **Title**: Understanding the Dataset <br>
#
# **Task**: For the given datasets below, identify the data types and dimensions.<br>
#
# Task 1: Employee Dataset<br>
# Columns: Employee ID , Name , Age , Department , Salary , Joining Date<br>
# Task 2: Product Sales Dataset<br>
# Columns: Product ID , Product Name , Price , Quantity Sold , Category , Sales Date<br>
# Task 3: Student Grades Dataset<br>
# Columns: Student ID , Student Name , Math Score , Science Score , English Score ,Year<br>
#
# Instructions:<br>
#
# Identify which columns are numerical (continuous or discrete) and which are categorical
# (nominal or ordinal).<br>
# Note down the dimensions (number of rows and columns) of the dataset.

# %%
import pandas as pd

# Task 1: Employee Dataset
employee_data = {
    'Employee ID': [1, 2, 3, 4],
        'Name': ['Alice', 'Bob', 'Charlie', 'David'],
            'Age': [29, 34, 23, 45],
                'Department': ['HR', 'IT', 'Finance', 'Sales'],
                    'Salary': [50000, 60000, 45000, 70000],
                        'Joining Date': ['2021-06-01', '2020-08-15', '2019-02-22', '2018-11-10']
                        }
employee_df = pd.DataFrame(employee_data)

# Task 2: Product Sales Dataset
product_sales_data = {
    'Product ID': [101, 102, 103, 104],
        'Product Name': ['Laptop', 'Mobile', 'Tablet', 'Monitor'],
            'Price': [1000, 500, 300, 200],
                'Quantity Sold': [150, 200, 250, 100],
                    'Category': ['Electronics', 'Electronics', 'Electronics', 'Electronics'],
                        'Sales Date': ['2021-12-01', '2021-12-02', '2021-12-03', '2021-12-04']
                        }
product_sales_df = pd.DataFrame(product_sales_data)

# Task 3: Student Grades Dataset
student_grades_data = {
    'Student ID': [1, 2, 3, 4],
        'Student Name': ['John', 'Emma', 'Sophia', 'Oliver'],
            'Math Score': [85, 92, 78, 88],
                'Science Score': [90, 89, 84, 91],
                    'English Score': [80, 91, 79, 85],
                        'Year': [2021, 2021, 2021, 2021]
                        }
student_grades_df = pd.DataFrame(student_grades_data)

# Identify data types and dimensions for each dataset
employee_df_info = {
    'Data Types': employee_df.dtypes,
        'Dimensions': employee_df.shape
        }
product_sales_df_info = {
        'Data Types': product_sales_df.dtypes,
            'Dimensions': product_sales_df.shape
            }

student_grades_df_info = {
    'Data Types': student_grades_df.dtypes,
        'Dimensions': student_grades_df.shape
        }

employee_df_info, product_sales_df_info, student_grades_df_info
# Out:
# ({'Data Types': Employee ID      int64
#   Name            object
#   Age              int64
#   Department      object
#   Salary           int64
#   Joining Date    object
#   dtype: object,
#   'Dimensions': (4, 6)},
#  {'Data Types': Product ID        int64
#   Product Name     object
#   Price             int64
#   Quantity Sold     int64
#   Category         object
#   Sales Date       object
#   dtype: object,
#   'Dimensions': (4, 6)},
#  {'Data Types': Student ID        int64
#   Student Name     object
#   Math Score        int64
#   Science Score     int64
#   English Score     int64
#   Year              int64
#   dtype: object,
#   'Dimensions': (4, 6)})

# %% [markdown]
# **Title**: Checking for Missing Values<br>
#
# **Task**: Identify and count the number of missing values in each dataset.<br>
#
# Instructions:<br>
# Use Python or any data manipulation tool to check for missing values in each column of the datasets. <br>Report the columns which have missing values and their counts.

# %%
# Task: Checking for Missing Values

# Check for missing values in Employee Dataset
employee_missing_values = employee_df.isnull().sum()

# Check for missing values in Product Sales Dataset
product_sales_missing_values = product_sales_df.isnull().sum()

# Check for missing values in Student Grades Dataset
student_grades_missing_values = student_grades_df.isnull().sum()

employee_missing_values, product_sales_missing_values, student_grades_missing_values
# Out:
# (Employee ID     0
#  Name            0
#  Age             0
#  Department      0
#  Salary          0
#  Joining Date    0
#  dtype: int64,
#  Product ID       0
#  Product Name     0
#  Price            0
#  Quantity Sold    0
#  Category         0
#  Sales Date       0
#  dtype: int64,
#  Student ID       0
#  Student Name     0
#  Math Score       0
#  Science Score    0
#  English Score    0
#  Year             0
#  dtype: int64)

# %% [markdown]
# **Title**: Handling Outliers<br>
#
# **Task**: Detect and propose handling methods for outliers in the numerical columns of the datasets.<br>
#
# Task 1: Age in Employee Dataset<br>
# Task 2: Price in Product Sales Dataset<br>
# Task 3: Math Score in Student Grades Dataset<br>
#
# Instructions:<br>
#
# Use box plots to visualize potential outliers.<br>
# Suggest methods to handle them, such as removal or transformation.

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Task 1: Age in Employee Dataset
plt.figure(figsize=(8, 6))
sns.boxplot(x=employee_df['Age'])
plt.title('Boxplot of Age in Employee Dataset')
plt.show()

# Task 2: Price in Product Sales Dataset
plt.figure(figsize=(8, 6))
sns.boxplot(x=product_sales_df['Price'])
plt.title('Boxplot of Price in Product Sales Dataset')
plt.show()

# Task 3: Math Score in Student Grades Dataset
plt.figure(figsize=(8, 6))
sns.boxplot(x=student_grades_df['Math Score'])
plt.title('Boxplot of Math Score in Student Grades Dataset')
plt.show()

# %% [markdown]
# **Title**: Visualizing Data Distributions<br>
#
# **Task**: Create visualizations for data distributions.<br>
#
# Task 1: Histogram for Age in Employee Dataset<br>
# Task 2: Distribution plot for Price in Product Sales Dataset<br>
# Task 3: Histogram for Math Score in Student Grades Dataset
#
# Instructions:<br>
#
# Use matplotlib or seaborn in Python to create the plots.<br>
# Comment on the skewness or normality of the distributions.

# %%
plt.figure(figsize=(6, 4))
plt.hist(employee_df['Age'], bins=10, edgecolor='black')
plt.title('Age Distribution - Employee Dataset')
plt.show()

plt.figure(figsize=(6, 4))
sns.histplot(product_sales_df['Price'], kde=True)
plt.title('Price Distribution - Product Sales Dataset')
plt.show()

plt.figure(figsize=(6, 4))
plt.hist(student_grades_df['Math Score'], bins=10, edgecolor='black')
plt.title('Math Score Distribution - Student Grades Dataset')
plt.show()

# %% [markdown]
# **Title**: Finding Relationships Between Features<br>
#
# **Task**: Identify relationships between pairs of features in the datasets.<br>
#
# Task 1: Salary vs Age in Employee Dataset<br>
# Task 2: Price vs Quantity Sold in Product Sales Dataset<br>
# Task 3: Math Score vs Science Score in Student Grades Dataset
#
# Instructions: <br>
#
# Use scatter plots or correlation coefficients to analyze the relationships.<br>
# Describe any insights or patterns observed.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# Sample Employee Dataset
employee_data = pd.DataFrame({
    'Employee ID': [101, 102, 103, 104, 105],
        'Name': ['Alice', 'Bob', 'Charlie', 'David', 'Eva'],
            'Age': [25, 30, 45, 35, 50],
                'Salary': [50000, 60000, 80000, 70000, 90000]
                })
# Sample Product Sales Dataset
sales_data = pd.DataFrame({
    'Product ID': [1, 2, 3, 4, 5],
        'Price': [10, 20, 15, 25, 30],
            'Quantity Sold': [100, 150, 120, 80, 60]
            })

# Sample Student Grades Dataset
grades_data = pd.DataFrame({
    'Student ID': [201, 202, 203, 204, 205],
        'Math Score': [75, 85, 95, 65, 80],
            'Science Score': [70, 88, 90, 60, 82]
            })
# Task 1: Salary vs Age
sns.scatterplot(data=employee_data, x='Age', y='Salary')
plt.title('Salary vs Age')
plt.show()

# Task 2: Price vs Quantity Sold
sns.scatterplot(data=sales_data, x='Price', y='Quantity Sold')
plt.title('Price vs Quantity Sold')
plt.show()

# Task 3: Math Score vs Science Score
sns.scatterplot(data=grades_data, x='Math Score', y='Science Score')
plt.title('Math Score vs Science Score')
plt.show()

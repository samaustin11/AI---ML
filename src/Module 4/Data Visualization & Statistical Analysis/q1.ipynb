# %% [markdown]
# Title: Histogram of a Single Feature <br>
#
# Question 1: Create a histogram for the age feature from a dataset. Interpret what the shape of the histogram tells us about the distribution of the age feature.

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# Create a mock dataset with an 'age' column
np.random.seed(0)
data = pd.DataFrame({
    'age': np.random.normal(loc=35, scale=10, size=1000).astype(int)
    })
# Plot histogram
plt.hist(data['age'], bins=20, edgecolor='black')
plt.title('Histogram of Age')
plt.xlabel('Age')
plt.ylabel('Frequency')
plt.grid(True)
plt.show()

# %% [markdown]
# Title: Boxplot for a Single Feature <br>
#
# Question 2: Generate a boxplot for the salary feature and identify any outliers.

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# Create a mock dataset with a 'salary' column
np.random.seed(1)
data = pd.DataFrame({
    'salary': np.append(np.random.normal(loc=50000, scale=8000, size=990), [120000, 130000, 150000, 160000, 200000])
    })
# Plot boxplot
plt.boxplot(data['salary'], vert=False)
plt.title('Boxplot of Salary')
plt.xlabel('Salary')
plt.grid(True)
plt.show()

# %% [markdown]
# Title: Violin Plot of a Single Feature <br>
#
# Question 3: Use a violin plot to visualize the distribution of the height feature and comment on its shape.

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import pandas as pd

# Create a mock dataset with a 'height' column
np.random.seed(2)
data = pd.DataFrame({
    'height': np.random.normal(loc=170, scale=10, size=1000)
    })

# Plot violin plot
sns.violinplot(x=data['height'])
plt.title('Violin Plot of Height')
plt.xlabel('Height')
plt.grid(True)
plt.show()

# %% [markdown]
# Title: Scatter Plot to Analyze Relationship<br>
#
# Question 4: Create a scatter plot for the weight and height features to determine if there is a trend.

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# Generate sample data
np.random.seed(3)
height = np.random.normal(170, 10, 200)
weight = height * 0.45 + np.random.normal(0, 5, 200)

df = pd.DataFrame({'height': height, 'weight': weight})

# Scatter plot
plt.scatter(df['height'], df['weight'], alpha=0.7)
plt.title('Scatter Plot of Height vs. Weight')
plt.xlabel('Height')
plt.ylabel('Weight')
plt.grid(True)
plt.show()

# %% [markdown]
# Title: Correlation Heatmap<br>
#
# Question 5 : Generate a correlation heatmap for a dataset with multiple features (e.g., height ,weight , age ) and explain the correlations observed.

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import pandas as pd

# Generate sample data
np.random.seed(4)
height = np.random.normal(170, 10, 200)
weight = height * 0.45 + np.random.normal(0, 5, 200)
age = np.random.randint(18, 65, 200)

df = pd.DataFrame({'height': height, 'weight': weight, 'age': age})

# Correlation heatmap
plt.figure(figsize=(6, 4))
sns.heatmap(df.corr(), annot=True, cmap='coolwarm', fmt='.2f')
plt.title('Correlation Heatmap')
plt.tight_layout()
plt.show()

# %% [markdown]
# Title: Descriptive Statistical Analysis<br>
#
# Question 6: Calculate the mean, median, standard deviation, skewness, and kurtosis for the
# temperature feature and discuss the results.

# %%
import numpy as np
import pandas as pd
from scipy.stats import skew, kurtosis

# Generate synthetic temperature data
np.random.seed(5)
temperature = np.random.normal(loc=25, scale=5, size=200)

# Create DataFrame
df = pd.DataFrame({'temperature': temperature})

# Descriptive statistics
mean_val = df['temperature'].mean()
median_val = df['temperature'].median()
std_dev = df['temperature'].std()
skewness = skew(df['temperature'])
kurt = kurtosis(df['temperature'])

print(f"Mean: {mean_val:.2f}")
print(f"Median: {median_val:.2f}")
print(f"Standard Deviation: {std_dev:.2f}")
print(f"Skewness: {skewness:.2f}")
print(f"Kurtosis: {kurt:.2f}")
# Out:
# Mean: 25.30
# Median: 24.99
# Standard Deviation: 4.93
# Skewness: -0.01
# Kurtosis: 0.02

# %% [markdown]
# Title: Covariance and Correlation between Two Features<br>
#
# Question 7: Compute the covariance and correlation between price and demand in a dataset.
# Explain what these metrics indicate.

# %%
import numpy as np
import pandas as pd

# Generate synthetic data
np.random.seed(7)
price = np.random.normal(50, 10, 100)
demand = 200 - price + np.random.normal(0, 5, 100)  # inverse relationship

# Create DataFrame
df = pd.DataFrame({'price': price, 'demand': demand})

# Covariance
covariance = df[['price', 'demand']].cov().iloc[0, 1]

# Correlation
correlation = df[['price', 'demand']].corr().iloc[0, 1]

print(f"Covariance between price and demand: {covariance:.2f}")
print(f"Correlation between price and demand: {correlation:.2f}")
# Out:
# Covariance between price and demand: -108.92
# Correlation between price and demand: -0.91

# %% [markdown]
# Title: Pair Plot for Multivariate Analysis<br>
#
# Question 8: Utilize a pair plot on a dataset to explore the relationships and distributions between
# height , weight , and age . What insights can you glean from this visualization?

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# Generate synthetic dataset
np.random.seed(0)
data = pd.DataFrame({
    'height': np.random.normal(170, 10, 100),
        'weight': np.random.normal(70, 15, 100),
            'age': np.random.normal(35, 12, 100)
            })
# Pair plot
sns.pairplot(data)
plt.show()

# %% [markdown]
# Title: Principal Component Analysis (PCA)<br>
#
# Question 9 : Apply PCA on a dataset with multiple features (e.g., x1 , x2 , x3 , x4 ) and reduce it to two principal components. Visualize the data in the new feature space.

# %%
import pandas as pd
import numpy as np
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler
import matplotlib.pyplot as plt

# Generate synthetic dataset
np.random.seed(42)
X = pd.DataFrame({
    'x1': np.random.rand(100),
        'x2': np.random.rand(100),
            'x3': np.random.rand(100),
                'x4': np.random.rand(100)
                })

# Standardize the data
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# Apply PCA
pca = PCA(n_components=2)
X_pca = pca.fit_transform(X_scaled)

# Create a DataFrame for PCA results
pca_df = pd.DataFrame(X_pca, columns=['PC1', 'PC2'])

# Plot the principal components
plt.scatter(pca_df['PC1'], pca_df['PC2'])
plt.xlabel('Principal Component 1')
plt.ylabel('Principal Component 2')
plt.title('PCA Result (2 Components)')
plt.grid(True)
plt.show()

# %% [markdown]
# Title: Advanced Pair Plot with Hue Parameter<br>
#
# Question 10 : Create a pair plot for height , weight , and age with an added categorical variable gender as the hue to observe different group trends.

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# Generate synthetic dataset
np.random.seed(0)
data = pd.DataFrame({
    'height': np.random.normal(170, 10, 100),
        'weight': np.random.normal(70, 15, 100),
            'age': np.random.randint(18, 60, 100),
                'gender': np.random.choice(['Male', 'Female'], 100)
                })

# Create pair plot with hue
sns.pairplot(data, hue='gender', vars=['height', 'weight', 'age'])
plt.show()
